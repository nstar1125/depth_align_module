# %%
import os
import numpy as np
import matplotlib.pyplot as plt

depth_path = "./input/mono_depth"

count = 0
for file in sorted(os.listdir(depth_path)):
    # .npy 파일 로드
    if file.endswith("_aligned.npy"): #_aligned
        print(file)
        depth_map = np.load(os.path.join(depth_path, file))
        # 시각화
        plt.imshow(depth_map, cmap='viridis')
        plt.colorbar()
        plt.show()
        break
# Out:
# 000000000_aligned.npy
